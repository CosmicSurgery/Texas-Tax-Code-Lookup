# %%
import usaddress
import pandas as pd
import numpy as np
import collections

# %%
df = pd.read_excel('Test Data Texas.xlsx',sheet_name=1)

# %%
df
# Out:
#       Qty  Sales Price  Amount  Tax Amount  Taxable Amount             Class  \
# 0     1.0        28.00   28.00        0.00           28.00  Website:Facebook
# 1     1.0        18.99   18.99        0.00           18.99  Website:Facebook
# 2     1.0         9.24    9.24        6.21            9.24  Website:Facebook
# 3     1.0        40.99   40.99        0.00           40.99           Website
# 4     1.0        40.99   40.99        0.00           40.99           Website
# ...   ...          ...     ...         ...             ...               ...
# 1024  NaN          NaN  -25.35        0.00            0.00     Online Retail
# 1025 -2.0        47.00  -94.00        0.00            0.00     Online Retail
# 1026 -1.0        45.00  -45.00        0.00            0.00     Online Retail
# 1027  NaN          NaN  -25.70        0.00            0.00     Online Retail
# 1028 -2.0        25.00  -50.00        0.00            0.00         Wholesale
#
#             Location                                   Shipping Address  \
# 0            WEBSITE  Robin Romans,7005 Rain Creek Pkwy,Austin, Texa...
# 1            WEBSITE  Robin Romans,7005 Rain Creek Pkwy,Austin, Texa...
# 2            WEBSITE  Robin Romans,7005 Rain Creek Pkwy,Austin, Texa...
# 3            WEBSITE  Tom Mackowski,6905 Nottoway Lane,Lumberton Tex...
# 4            WEBSITE  Tom Mackowski,6905 Nottoway Lane,Lumberton Tex...
# ...              ...                                                ...
# 1024  Wholesale - TX                                                NaN
# 1025  Wholesale - TX                                                NaN
# 1026  Wholesale - TX                                                NaN
# 1027  Wholesale - TX                                                NaN
# 1028  Wholesale - TX                                                  0
#
#      Shipping Zip State
# 0           78759    TX
# 1           78759    TX
# 2           78759    TX
# 3           77657    TX
# 4           77657    TX
# ...           ...   ...
# 1024        75039    TX
# 1025        75039    TX
# 1026        75039    TX
# 1027        75039    TX
# 1028        76182    TX
#
# [1029 rows x 10 columns]

# %%
l = df['Shipping Address'].to_numpy()
j = []

for i,k in enumerate(l):
    if type(k) is str:
        l[i] = l[i].replace('_x000D_\n',',')
        l[i] = l[i].replace('\n',',')
        try:
            j.append(usaddress.tag(l[i])[0])
        except:
            j.append(collections.OrderedDict([('Recipient','bad')]))

new_df = pd.DataFrame(j)
# new_df.to_excel('test.xlsx')
# print(new_df.head(10))

# %%
len(new_df)
# Out:
# 1020

# %%
new_df['test'] =

# %%
(new_df['AddressNumber'] + ' ' + new_df['StreetName']).to_numpy()
# Out:
# array(['7005 Rain Creek', '7005 Rain Creek', '7005 Rain Creek', ...,
#        '30303 Oak Tree', '30303 Oak Tree', '4041 Hidden Valley'],
#       dtype=object)

# %%
for k in new_df:
    print(k)
    print(i)
    # print(' '.join(new_df.iloc[i][['AddressNumber', 'StreetName']]))
# Out:
# Recipient
# AddressNumber
# StreetName
# StreetNamePostType
# PlaceName
# StateName
# ZipCode
# CountryName
# StreetNamePreDirectional
# OccupancyIdentifier
# BuildingName
# StreetNamePreType
# OccupancyType
# USPSBoxType
# USPSBoxID
# SubaddressType
# SubaddressIdentifier
# StreetNamePostDirectional

# %%
new_df
# Out:
#                                           Recipient AddressNumber  \
# 0                                      Robin Romans          7005
# 1                                      Robin Romans          7005
# 2                                      Robin Romans          7005
# 3                                     Tom Mackowski          6905
# 4                                     Tom Mackowski          6905
# ...                                             ...           ...
# 1015  Hanna Avdey, McGuire Moorman Hospitality, LLC          1711
# 1016  Hanna Avdey, McGuire Moorman Hospitality, LLC          1711
# 1017                                     Lori Smith         30303
# 1018                                     Lori Smith         30303
# 1019                                   Lisa Crawley          4041
#
#          StreetName StreetNamePostType   PlaceName StateName     ZipCode  \
# 0        Rain Creek               Pkwy      Austin     Texas  78759-7030
# 1        Rain Creek               Pkwy      Austin     Texas  78759-7030
# 2        Rain Creek               Pkwy      Austin     Texas  78759-7030
# 3          Nottoway               Lane   Lumberton     Texas       77657
# 4          Nottoway               Lane   Lumberton     Texas       77657
# ...             ...                ...         ...       ...         ...
# 1015       Congress               Ave.      Austin        TX       78704
# 1016       Congress               Ave.      Austin        TX       78704
# 1017       Oak Tree              Drive  Georgetown     Texas       78628
# 1018       Oak Tree              Drive  Georgetown     Texas       78628
# 1019  Hidden Valley                Dr.     DENISON     Texas       75020
#
#         CountryName StreetNamePreDirectional OccupancyIdentifier BuildingName  \
# 0     United States                      NaN                 NaN          NaN
# 1     United States                      NaN                 NaN          NaN
# 2     United States                      NaN                 NaN          NaN
# 3     United States                      NaN                 NaN          NaN
# 4     United States                      NaN                 NaN          NaN
# ...             ...                      ...                 ...          ...
# 1015            NaN                       S.                 2nd          NaN
# 1016            NaN                       S.                 2nd          NaN
# 1017  United States                      NaN                 NaN          NaN
# 1018  United States                      NaN                 NaN          NaN
# 1019  United States                      NaN                 NaN          NaN
#
#      StreetNamePreType OccupancyType USPSBoxType USPSBoxID SubaddressType  \
# 0                  NaN           NaN         NaN       NaN            NaN
# 1                  NaN           NaN         NaN       NaN            NaN
# 2                  NaN           NaN         NaN       NaN            NaN
# 3                  NaN           NaN         NaN       NaN            NaN
# 4                  NaN           NaN         NaN       NaN            NaN
# ...                ...           ...         ...       ...            ...
# 1015               NaN         Floor         NaN       NaN            NaN
# 1016               NaN         Floor         NaN       NaN            NaN
# 1017               NaN           NaN         NaN       NaN            NaN
# 1018               NaN           NaN         NaN       NaN            NaN
# 1019               NaN           NaN         NaN       NaN            NaN
#
#      SubaddressIdentifier StreetNamePostDirectional
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
# ...                   ...                       ...
# 1015                  NaN                       NaN
# 1016                  NaN                       NaN
# 1017                  NaN                       NaN
# 1018                  NaN                       NaN
# 1019                  NaN                       NaN
#
# [1020 rows x 18 columns]

# %%
j[0][0]
# Out:
# OrderedDict([('Recipient', 'Robin Romans'),
#              ('AddressNumber', '7005'),
#              ('StreetName', 'Rain Creek'),
#              ('StreetNamePostType', 'Pkwy'),
#              ('PlaceName', 'Austin'),
#              ('StateName', 'Texas'),
#              ('ZipCode', '78759-7030'),
#              ('CountryName', 'United States')])

# %%
j[0][0].keys()
# Out:
# odict_keys(['Recipient', 'AddressNumber', 'StreetName', 'StreetNamePostType', 'PlaceName', 'StateName', 'ZipCode', 'CountryName'])

# %%
new_df = pd.DataFrame(columns = j[0]
