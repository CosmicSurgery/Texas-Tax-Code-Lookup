# %%
import usaddress
import pandas as pd
import numpy as np
import collections

# %%
df = pd.read_excel('Test Data Texas2.xlsx')
df
# Out:
#     order date entry person  old cust nbr                 customer name  \
# 0   2024-01-23          API        8802.0             AMAZON PS - LOC 2
# 1   2024-01-25          API        8813.0             AMAZON PS - LOC 4
# 2   2024-01-26          API        9934.0  WALMART MARKETPLACE PS LOC 4
# 3   2024-01-22          API        8813.0             AMAZON PS - LOC 4
# 4   2024-01-23     INTERNET           NaN              C Jett oil tools
# ..         ...          ...           ...                           ...
# 776 2024-01-09          API        8802.0             AMAZON PS - LOC 2
# 777 2024-01-13     INTERNET           NaN               Xavier Granados
# 778 2024-01-02          EDI        9570.0         ZORO TOOLS PS - LOC 5
# 779 2024-01-23     INTERNET           NaN                A-1Escort Ser.
# 780 2024-01-19          API        9934.0  WALMART MARKETPLACE PS LOC 4
#
#     order type invoice type  ship date  cap  division  ship mer amt  ship tax  \
# 0          CHG           SI 2024-01-23    1        12         21.77      0.00
# 1          CHG           SI 2024-01-26    1        12        116.18      0.00
# 2          CHG           SI 2024-01-29    1        12         45.96      0.00
# 3          CHG           SI 2024-01-22    1        12          8.09      0.00
# 4         CASH           SI 2024-01-24    2        12        774.00     48.38
# ..         ...          ...        ...  ...       ...           ...       ...
# 776        CHG           SI 2024-01-10    1        12         27.11      0.00
# 777       CASH           SI 2024-01-15    2        12         58.96      4.86
# 778        CHG           SI 2024-01-03    2        12         69.60      0.00
# 779       CASH           SI 2024-01-24    2        12        391.00     26.39
# 780        CHG           SI 2024-01-19    1        12         63.36      0.00
#
#                   ship to address1       ship to address2 ship to city  \
# 0    353 anderson county road 2139                    NaN    Palestine
# 1                     1510 Fm 3224                    NaN    Palestine
# 2             2301 Country Club Rd                    NaN    Palestine
# 3         5765 E State Highway 294                    NaN      Elkhart
# 4               Attn: Corey Bruton           2277 Se 2800      Andrews
# ..                             ...                    ...          ...
# 776             13116 Coriander Dr                    NaN       Austin
# 777           109 N Tranquility Dr                    NaN    La Vernia
# 778                   Buffie Pryor       1870 Illinois St        Rhome
# 779            Attn: Randy Warnell  109 Private Road 1309   Bridgeport
# 780                824 Virginia St                    NaN       Graham
#
#     ship to state ship to zip  Zip 5      County
# 0              TX       75801  75801    Anderson
# 1              TX  75803-2169  75803    Anderson
# 2              TX  75803-8339  75803    Anderson
# 3              TX  75839-3135  75839    Anderson
# 4              TX  79714-5771  79714     Andrews
# ..            ...         ...    ...         ...
# 776            TX  78729-6472  78729  Williamson
# 777            TX  78121-5504  78121      Wilson
# 778            TX       76078  76078        Wise
# 779            TX  76426-6207  76426        Wise
# 780            TX  76450-3528  76450       Young
#
# [781 rows x 18 columns]

# %%
def combine_columns(row):
    return str(row['ship to address1'].fillna('')) + str(df['ship to address2'].fillna(''))

# %%
df['ship to address2'].fillna('')
# Out:
# 0
# 1
# 2
# 3
# 4               2277 Se 2800
#                ...
# 776
# 777
# 778         1870 Illinois St
# 779    109 Private Road 1309
# 780
# Name: ship to address2, Length: 781, dtype: object

# %%
df['Combined'] = df.apply(combine_columns, axis=1)
df['Combined'].iloc[1]
# Out:
# '1510 Fm 32240                           \n1                           \n2                           \n3                           \n4               2277 Se 2800\n               ...          \n776                         \n777                         \n778         1870 Illinois St\n779    109 Private Road 1309\n780                         \nName: ship to address2, Length: 781, dtype: object'

# %%
for i in range(len(df)):
    print(df['ship to address1'].iloc[i] + ', ' + str(df['ship to address2'].fillna('').iloc[i]))
# Out:
# 353 anderson county road 2139,
# 1510 Fm 3224,
# 2301 Country Club Rd,
# 5765 E State Highway 294,
# Attn: Corey Bruton, 2277 Se 2800
# 1613 Se 3101,
# 907 PERISHING,
# XXXXX,
# XXXXX,
# XXXXX,
# XXXXX,
# 14151 W Fm 2790 S,
# 817 N Bryant St Ste C,
# Attn: Jennifer Sullivan, 1324 Kloecker Rd
# 594 Upper Moffett Rd 113,
# 594 Upper Moffett Rd 113,
# Attn: Jeff Wise, 660 Nw Loop 230
# 386 Highway 304,
# Attn: Brandon Berdoll, 4754 Fm 535
# 1442 Old Mcdade Rd,
# 3712 E VETERANS MEMORIAL BLVD,
# 1226 East Us Hwy 190,
# 1822 Duce Spur,
# 710 Swanner Loop,
# 12502 Salado Springs Cir,
# 1333 Buena Vista St,
# XXXXX,
# XXXXX,
# 6100 Bandera Road Suite 304,
# 8802 Tradewind Dr, Apt 415
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 for i in range(len(df)):
# ----> 2     print(df['ship to address1'].iloc[i] + ', ' + str(df['ship to address2'].fillna('').iloc[i]))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
list_add = []
j = []
for i in range(len(df)):
    list_add.append(str(df['ship to address1'].iloc[i]) + ', ' + str(df['ship to address2'].fillna('').iloc[i]))
    try:
        j.append(usaddress(tag(list_add[-1]))
    except:
        j.append(collections.OrderedDict([('Recipient','bad')]))
new_df = pd.DataFrame(list_add)
new_df.head(10)
# Out:
#                                   0
# 0   353 anderson county road 2139,
# 1                    1510 Fm 3224,
# 2            2301 Country Club Rd,
# 3        5765 E State Highway 294,
# 4  Attn: Corey Bruton, 2277 Se 2800
# 5                    1613 Se 3101,
# 6                   907 PERISHING,
# 7                           XXXXX,
# 8                           XXXXX,
# 9                           XXXXX,

# %%
list_add
# Out:
# ['353 anderson county road 2139, ',
#  '1510 Fm 3224, ',
#  '2301 Country Club Rd, ',
#  '5765 E State Highway 294, ',
#  'Attn: Corey Bruton, 2277 Se 2800',
#  '1613 Se 3101, ',
#  '907 PERISHING, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '14151 W Fm 2790 S, ',
#  '817 N Bryant St Ste C, ',
#  'Attn: Jennifer Sullivan, 1324 Kloecker Rd',
#  '594 Upper Moffett Rd 113, ',
#  '594 Upper Moffett Rd 113, ',
#  'Attn: Jeff Wise, 660 Nw Loop 230',
#  '386 Highway 304, ',
#  'Attn: Brandon Berdoll, 4754 Fm 535',
#  '1442 Old Mcdade Rd, ',
#  '3712 E VETERANS MEMORIAL BLVD, ',
#  '1226 East Us Hwy 190, ',
#  '1822 Duce Spur, ',
#  '710 Swanner Loop, ',
#  '12502 Salado Springs Cir, ',
#  '1333 Buena Vista St, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '6100 Bandera Road Suite 304, ',
#  '8802 Tradewind Dr, Apt 415',
#  '6134, ',
#  '8722506, 5757 Farinon Dr',
#  '8033 Orchard Bend St, ',
#  '8033 Orchard Bend St, ',
#  '20770 Hwy 281 N, Suite 108-107',
#  '2715 Running Fawn, ',
#  '10018 Ramblin River Rd, ',
#  '10025 Shepherd Rd Lot 2, ',
#  '16321 Shepherd Rd # 122, ',
#  '12980 Interstate 35 S, ',
#  '4229 Fort Palmer Blvd, ',
#  '1039 W Hildebrand Ave, ',
#  '1401 Patricia Apt 407, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '922 Isom Rd, Ste 300',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '5230 Eisenhauer Rd, ',
#  '3453 N Panam Expy, Ste 303',
#  '4634 S Presa St, ',
#  '7500 Callaghan Rd Apt 146, ',
#  '3003 Old Elm Way, ',
#  '3111 Quakertown Dr, ',
#  '14923 Tropical Wind, ',
#  'XXXXX, ',
#  '5815 Rim Pass, ',
#  '6305 Camp Bullis Rd, ',
#  '6305 Camp Bullis Rd, ',
#  '24810 Flying Arrow, ',
#  '1534 Clementson Dr, ',
#  'Attn: Car Ram, 24303 Saffron Plum',
#  '214 Ej Ct, ',
#  'XXXXX, ',
#  'Jonathan Stahl, 1900 N. Fm 2148',
#  '4602 Woodstock Ln, ',
#  'XXXXX, ',
#  'Attn: Armando Gonzalez, 4701 Cr 424',
#  'Attn: Jennette Thompson, 4344 South Main',
#  'Johnny Flores, 3730 S. Main St.',
#  'Attn: Robert Harris, 17206 Pearland Sites Rd',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '1001 Main St, ',
#  '171 County Road 373, ',
#  '2132 Country Club Dr, ',
#  'Attn: Jennette Thompson, 4344 S Main St',
#  'Attn: Jennette Thompson, 4344 S Main St',
#  '3706 Sheldon Dr, ',
#  '2907 VILLA MARIA, ',
#  '2907 VILLA MARIA, ',
#  '2907 VILLA MARIA, ',
#  '2907 VILLA MARIA, ',
#  '1502 HARVEY RD, ',
#  '1502 HARVEY RD, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'Attn: Jeff Mcbride, 721 W Commerce',
#  'XXXXX, ',
#  '4705 Fm 696, ',
#  'XXXXX, ',
#  '124 Cinnamon Loop, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '7030 E Fm 1431, ',
#  '126 Foxwood Trl, ',
#  '411 Lariat Ln, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '1501 North Loop 499, Lot 360',
#  'Attn: Mario Chaney, 1500 Gulf Boulevard',
#  'Flavio Marquez, 292 Kings Hwy',
#  'Alberto Caraveo, 724 Pine Falls Dr',
#  '1631 Lincoln St, ',
#  '28051 E Mile 3 Rd, ',
#  'XXXXX, ',
#  '11419 Sunnyside Dr, Anderson',
#  '535 W Leblanc St, ',
#  '732 San Antonio St, Casa',
#  '2100 Purdue St, ',
#  'XXXXX, ',
#  '6913 K Ave #307, ',
#  'Attn: Jon Chamberlain, 3336 State Hwy 78 N Suite 5',
#  '2803 Skyview Dr, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '13293 Tabasco Cat Dr, ',
#  'XXXXX, ',
#  'Attn: Gilder Garcia, 115 Lakeway Trl',
#  '2650 S Mcdonald St Apt 3209, ',
#  '1111 Coleman St, ',
#  '7951 Col Mckiney Pkwy, Apt 3046',
#  'Attn: Scott Harding, 3804 Landsdowne Dr',
#  '2517 Evans Dr, ',
#  'Attn: Berry Kaufman, 4131 Paddock Ln',
#  '821 Martin Creek Dr, ',
#  '2000 N Highway 78, 2000 N HIGHWAY 78',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '1356 Fm 1890, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '555 Northgate Cir, ',
#  '218 Dry Bear Crk, ',
#  '105 N Middle Ln, ',
#  '20931 Klein Cir, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '5547 Stormie Keep, ',
#  '804 N Travis St, ',
#  '714 S Elizabeth St, ',
#  '4200 Beltway Dr., ',
#  'Attn: Lisa Goerdt, 2101 Midway Road Suite 350',
#  'Attn: Rigoberto Leon, 616 E Ave. J',
#  'Attn: Rigoberto Leon, 616 E Ave. J',
#  '905 AVE "T", SUITE 312',
#  'Attn: Rigoberto Leon, 616 E Ave. J',
#  '825 N BELTLINE RD, ',
#  'Attn: Richard Vazquez, 2615 Big Town Blvd',
#  'XXXXX, ',
#  'XXXXX, ',
#  '2516 IRVING BLVD, ',
#  '2516 IRVING BLVD, ',
#  '2516 IRVING BLVD, ',
#  '2516 IRVING BLVD, ',
#  '2516 IRVING BLVD, ',
#  '2516 IRVING BLVD, ',
#  '2516 IRVING BLVD, ',
#  '145 Cole St, ',
#  '2516 IRVING BLVD, ',
#  'Kim Chow, 9494 Larga Drive',
#  'XXXXX, ',
#  'Jared Espinoza, 7114 Harry Hines Blvd.',
#  'Sam Walker, 4610 Mint Way',
#  'Sam Walker, 4610 Mint Way',
#  '5565 Red Bird Center Dr Suite 140, 0',
#  'Attn: Juan Hermosillo, 10925 Alder Cir',
#  'Attn: Juan Hermosillo, 10925 Alder Cir',
#  '10925 ALDER CIRCLE, ',
#  '10925 ALDER CIRCLE, ',
#  '10925 ALDER CIRCLE, ',
#  '6271 Highland Hills Dr, Leasing Office',
#  'Attn: Nicole Ellery, 9615 Arborhill Dr',
#  'Attn: Shane White, 10503 Forest Ln. Ste.140',
#  '2544 Elm St Ste 200, ',
#  'Amber Zuniga, 2117 Saint Francis Ave',
#  '1414 Bentwood Dr, ',
#  '560 Tacoma Dr 1121 Pizo Dos, ',
#  '707 Robbie Dr, Ste 100',
#  '605 Shadywood Ln, ',
#  '1219 Larkspur Dr, ',
#  '614 W Wheatland Rd Ste B, ',
#  '1400 N Bluegrove Rd, ',
#  'Attn: Michael Lincon, 1012 W Wintergreen Rd',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '1737 Rosemont St, ',
#  '6304 Palo Pinto Ave, ',
#  '11243 Carissa Cir, ',
#  '2622 Myrtle Springs Ave, ',
#  'Attn: David Haney, 2825 Storey Ln',
#  '5909 Desco Dr, ',
#  '10628 Ruth Ann Dr, ',
#  'XXXXX, ',
#  '3239 Latham Dr, ',
#  '1805 Royal Ln Ste 113, ',
#  '3336 Towerwood Dr, ',
#  '13780 BENCHMARK DR, ',
#  '13755 Hutton Dr Ste 100, ',
#  '10725 Sandhill Rd, Ste 107',
#  'Attn: Juan Hermosillo, 10925 Alder Cir',
#  '33333 LBJ FWY, ',
#  '33333 LBJ FWY, ',
#  '33333 LBJ FWY, ',
#  '33333 LBJ FWY, ',
#  '33333 LBJ FWY, ',
#  '33333 LBJ FWY, ',
#  '33333 LBJ FWY, ',
#  '33333 LBJ FWY, ',
#  '33333 LBJ FWY, ',
#  '4545 Spring Valley Rd Unit A06, ',
#  '1243 Majesty Dr, ',
#  '7247 Blythdale Dr, ',
#  'Attn: Robert Chesney, 7500 Forrest Dr',
#  '254 E FM 2449, ',
#  'Andrien Choplick, 141 Seaborn Road',
#  '2901 TRADE CTR, ',
#  '2901 TRADE CTR, ',
#  'Attn: Shandra Winchester, 400 Gerault Rd',
#  '2712 Brookwood Dr, ',
#  '9 Armstrong Dr, ',
#  'XXXXX, ',
#  '225 S Charles St, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'Traila 418 Buladora Dr, ',
#  '1226 DUNCAN STREET, ',
#  '1504 Long Rd, Denton Isd-Atc',
#  'XXXXX, ',
#  '501 Fox Creek Ct, ',
#  'XXXXX, ',
#  '1232 Golden Eagle Ct, ',
#  '7484 Pudin Hill Rd, ',
#  '4105 Couch Rd, ',
#  '4250 Dale Earnhardt Way Ste 100, ',
#  'XXXXX, ',
#  '911 Parks St, ',
#  'Attn: Raymond Waters, 421 S Meadow Ave',
#  'Attn: Charles Gray, 2810 HILLTOP DR',
#  '7202 Kinghorn Dr., ',
#  'Attn: Raymond Waters, 421 S Meadow Ave',
#  '421 S Meadow Ave, ',
#  'Attn: Raymond Waters, 421 S Meadow Ave',
#  'XXXXX, ',
#  'XXXXX, ',
#  'Attn: Zujia Liu, 2435 W 42nd St',
#  'Attn: Zujia Liu, 2435 W 42nd St',
#  '915 Park Drive, ',
#  'Attn: Brock Poe, 5807 Ybarra Ct',
#  '1356 LOMALAND DR, ',
#  '11501 ROJAS ST STE R1, ',
#  '724 Istanbul Cir, ',
#  'XXXXX, ',
#  '4920 Joe Wilson Rd, ',
#  'Attn: Zahidah Muhammad, 1200 Mars Rd',
#  'Attn: Phillip Young, 5128 Fm 66',
#  'XXXXX, ',
#  '3434 Newgate St, ',
#  '2680 Buffalo Ridge Dr, ',
#  '27017 N Us Hwy 377, ',
#  'Attn: Bob Becker, 175 Private Road 1705',
#  '1075 Fm 913, ',
#  '110 Caleta Cir, ',
#  'Kendra Nichols, 13003 Royal Drive',
#  'Attn: Antonio Rock, 10711 Cash Rd',
#  '9333 S SAM HOUSTON PKWY #400, ',
#  '9333 S SAM HOUSTON PKWY #400, ',
#  '2303 HURRICANE LANE, ',
#  'XXXXX, ',
#  'Attn: Mikalyn Conner, 5306 Baker Rd',
#  'Attn: Mikalyn Conner, 5306 Baker Rd',
#  'Attn: Mikalyn Conner, 5306 Baker Rd',
#  '13311 Kettler Rd, ',
#  '12600 Executive Dr, Stephen Keisler',
#  'Attn: Jennifer Chen, 15935 Morgan St',
#  '3534 Orchard Blossom Dr, ',
#  '13 Pecan Gorge Ct, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '103 NW 9TH, ',
#  'David Claflin, 925 Us Highway 180 W',
#  '5322 Avenue K, Kimari Merritt',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '2424 Avenue N, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '212 15th St, ',
#  '2518 39th Ave N, ',
#  '1108 Abbott Dr, ',
#  'Attn: John Price, 517 S. Adams',
#  'Attn: Receiving Clerk, 256 Sultemeier Moellering Rd',
#  '1751 Us Highway 59 N, ',
#  'Mike Steadman, 8201 Fm 2300',
#  'Attn: Tina Harrison, 498 Bethel-Cannon Rd Office',
#  'Attn: Tina Harrison, 498 Bethel-Cannon Rd Office',
#  '68 Willow Ln, ',
#  'Attn: Chris Armendarez, 26449 State Highway 56',
#  'Attn: Chris Armendarez, 26449 State Highway 56',
#  '1508 Vanderslice Rd, ',
#  '602 Lauren Ct, ',
#  '602 Lauren Ct, ',
#  '102 Timber Trl, ',
#  'Attn: Carlin Stanton, 1230 Pine St',
#  'Attn: Carlin Stanton, 1230 Pine St',
#  'XXXXX, ',
#  '12062 Fm 1696 Rd, ',
#  '17324 Bell North Dr, ',
#  '107 Colima St, ',
#  '2420 Missy Ln, ',
#  'XXXXX, ',
#  'Attn: Angie Gonzales, 4515 Hunter Rd',
#  '3304 Quail Run, ',
#  '2219 Co. Rd 60, ',
#  '1145 SOUTH HIGHWAY 96, ',
#  '425 N 5TH ST, ',
#  'Justin Camp, 4210 Gulf Fwy',
#  '1504 Wichman St, ',
#  '6867 WYNNWOOD LANE, ',
#  '901 ASHLAND ST, ',
#  '3539 OAK FOREST DRIVE, ',
#  '3539 OAK FOREST DRIVE, ',
#  '3539 OAK FOREST DRIVE, ',
#  '3539 OAK FOREST DRIVE, ',
#  '3539 OAK FOREST DRIVE, ',
#  'Diann Smith, 6734 Winton St',
#  'Accts Payable, 4025 Willowbend Blvd',
#  'XXXXX, ',
#  '15525 MILNER ROAD, ',
#  'Johnny West, 5750 North Sam Houston Parkway East',
#  'Debbie Neuman, 4714 Winfield Rd',
#  '13310 Luthe Rd, ',
#  '8815 EMMOTT RD SUITE# 700, ',
#  '7206 River Fern Dr., ',
#  'Darrell Kuykendall, 13310 Hempstead Highway',
#  'Attn: Marvin Macotto, 5829 West Sam Houston Pkwy N',
#  '15090 SOMMERMEYER SUITE# 100, ',
#  '1585 W SAM HOUSTON PKWY N #A, ',
#  'Karen Hart, 2002 Brittmoore Rd',
#  'Attn: Jackeline Lara, 7052 Grand Blvd',
#  'Attn: Rodolfo Mata, 11518 Kilburn Rd',
#  'Attn: Ryan Blankenburg, 16441 Space Center Blvd',
#  'Attn: Matthew Long, 12906 Aste Ln',
#  '11234 JONES RD WEST SUITE# B, ',
#  '860 Greens Pkwy, Ste 500',
#  'Tony Castro, 860 Greens Pkwy',
#  'Tony Castro, 860 Greens Pkwy',
#  '6705 Cypress Creek Parkway, ',
#  'Donald Covington, 7915 Fm 1960 W',
#  '14603 Quail Creek Court, ',
#  '7843 Chinon Cir, ',
#  'Attn: Larry Wolod, 14827 La Quinta Lane',
#  'Richard Morris, 3310 Frick Rd.',
#  '6430 MAYFAIR ST, ',
#  '6303 W 34TH ST, ',
#  '6303 W 34TH ST, ',
#  '6303 W 34TH ST, ',
#  '6303 W 34TH ST, ',
#  '6303 W 34TH ST, ',
#  '6303 W 34TH ST, ',
#  '322 Magnolia Point Dr, ',
#  '2400 S PERSIMMON STREET, ',
#  '2400 S PERSIMMON STREET, ',
#  '2400 S PERSIMMON STREET, ',
#  '2400 S PERSIMMON STREET, ',
#  '2400 S PERSIMMON STREET, ',
#  '2400 S PERSIMMON STREET, ',
#  '2400 S PERSIMMON STREET, ',
#  '2400 S PERSIMMON STREET, ',
#  '2400 S PERSIMMON STREET, ',
#  '19140 Northpine Dr., ',
#  'Melva Reyes, 21240 Foster Rd. Bldg. #3',
#  'Lawrence Zarker, 10326 Joshua Creek Ct',
#  'XXXXX, ',
#  '11002 Choate Rd, ',
#  'Ronda Nuce, 4117 Fair Drive',
#  'XXXXX, ',
#  'Bob Williams, 2001 Sheldon Road',
#  '2401 Andrews Ct, ',
#  '2002 Karbach St., ',
#  '6506 Providence River Ln, ',
#  'XXXXX, ',
#  '1615 Binz St, ',
#  '6606 Minola St, ',
#  '1301 Parker St, ',
#  '414 W 26th St, ',
#  '1422 Alexander St, ',
#  'Attn: Peter Silva, 3228 Maxroy St',
#  '6901 Avenue V, ',
#  '6740 Bracknell St, ',
#  '818 Town And Country Blvd, 4th Floor',
#  '3606 Bellefontaine St, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '8601 Havner Ct, ',
#  'XXXXX, ',
#  '6534 Guhn Rd, ',
#  '6534 Guhn Rd, ',
#  '6534 Guhn Rd, ',
#  'Attn: Donald Lewis, 7834 Fairview St',
#  '4314 Marchant Rd, ',
#  '1111 FELLOWS RD, TRUCK BAY 10 OR 11',
#  '1111 FELLOWS RD, TRUCK BAY 10 OR 11',
#  '1111 FELLOWS RD, TRUCK BAY 10 OR 11',
#  '8009 Turquoise Ln, ',
#  '6119 Westview Dr, ',
#  '6443 Burgoyne Rd, ',
#  '3226 Hillcroft St, ',
#  '3226 Hillcroft St, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '12450 Cutten Rd, ',
#  '11522 Pinole Lane Ct, ',
#  'XXXXX, ',
#  '12226 Moorcreek Dr, ',
#  '13215 Mills Rapids St, Davotney Rodriguez',
#  '4400 Boone Rd Apt 237, ',
#  'XXXXX, ',
#  '5419 Clarewood Dr, Ste B',
#  'XXXXX, ',
#  '3915 Forbesbury Dr, ',
#  'XXXXX, ',
#  '2207 Highland River Dr, ',
#  'XXXXX, ',
#  '7431 Curry Rd, ',
#  '17403 Fairgrove Park Dr, ',
#  '16523 Grenada Falls Dr, ',
#  '5478 Kuldell Dr, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '5311 Creek Shadows Dr, ',
#  '27905 Commercial Park Rd, Ste 410',
#  'XXXXX, ',
#  'Attn: Grant Holdsworth, 20002 Plaza 290 Blvd',
#  'XXXXX, ',
#  '19530 Country Mountain Ct, ',
#  'Attn: Lynn Hodge, 1230 Wilson Road Ct',
#  'XXXXX, ',
#  '11902 Via Davinci Ln, ',
#  '18015 Parkwille Ln, ',
#  'XXXXX, ',
#  '7611 Shavano Ln, ',
#  '17000 Premium Dr, ',
#  '22434 Wetherburn Ln, ',
#  'Attn: Andre Gerard, 6818 Pioneer Trl',
#  '5722 Tabula Rasa Dr, ',
#  '135 Fresa Rd, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '115 Avenue D, ',
#  '102 Saddlehorn Drive, ',
#  '6800 Waters Way, ',
#  '17401 Interstate 35, ',
#  '1151 Bunton Creek Rd Unit 503, ',
#  '1151 Bunton Creek Rd Unit 503, ',
#  '416 Mirafield Ln, ',
#  '10401 Signal Hill Rd, ',
#  'XXXXX, ',
#  '9770 State Hwy.  31 W, ',
#  '1101 NORTH 23RD STREET, ',
#  '1101 NORTH 23RD STREET, ',
#  '1341 W Business Highway 83, 294',
#  '311 S BRYAN RD SUITE# 200 A, ',
#  '704 W Ridge Rd, Building H',
#  'Attn: Angie Hernandez, 1300 S Border Ave Office',
#  'Rolando Herrera, 1230 El Faro Rd',
#  '701 E Austin Ave, ',
#  '15509 San Martin St, ',
#  'XXXXX, ',
#  '705 Cancun Apt 4, ',
#  '1215 Industrial Dr, ',
#  '1211 2nd St, ',
#  '1160 Monaco Rd, ',
#  '108 Industrial Dr Ste 100, ',
#  'XXXXX, ',
#  '3917 Seminole Trl, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '16074 N Fm 1584, ',
#  '113 N Main Street, ',
#  '3007 Travis St, ',
#  '177 Private Road 7020, ',
#  'XXXXX, ',
#  '10386 W Clubb Rd, ',
#  'Attn: Jessica Delacerda, 11800 Highway 90',
#  '2900 N Fm 157, Att:Bailey Yandell',
#  'Michael Chapman, 8124 Rose Creek Ct',
#  'Benjamin Powell, 3135 Chambers St',
#  '7924 Windy Hill Ln, ',
#  'XXXXX, ',
#  '1017 Chestnut Dr, ',
#  '981 N Highway 174, ',
#  '981 N Highway 174, ',
#  'XXXXX, ',
#  'Shane Hayes, 1421 Governors Blvd',
#  '1475 AKRON WAY, ',
#  '10864 Bradley Cir, ',
#  '6591 Shady Ln, ',
#  '7668 County Road 302, ',
#  '27140 Autumn Gln, ',
#  '211 River Oaks Rd, ',
#  '128 Ten West Dr, ',
#  '317 Sidney Baker St S, ',
#  '581 W State Hwy 285, 581 W State Hwy 285',
#  '330 Moffett Ave Bldg 758, ',
#  '6150 Laura Ln, ',
#  '701 N AVE C, ',
#  '881 County Road 358, ',
#  '403 S Monroe St, ',
#  '924 E Emory St, Apt 3202',
#  '5711 E Fm 40, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '2215 30th St, ',
#  '3401 95th St, ',
#  '201 Dale St, ',
#  '1929 S BRIDGE ST , PO BOX 726',
#  'Chris Simmers, 8401 Imperial Drive',
#  '801 HEWITT DR , PO BOX 20967',
#  '801 HEWITT DR , PO BOX 20967',
#  '801 HEWITT DR , PO BOX 20967',
#  'Dennis Layne Phipps, 910 La Salle Ave',
#  '102 Brandy Hill Rd, ',
#  '243 Pr 4315, #321',
#  '1651 Us Highway 90 W, ',
#  '601 Fm 1796, ',
#  'XXXXX, ',
#  'Lance Brooks, 1110 S Fm 1788 Suite 38-48',
#  '10109 W county rd 77, ',
#  '2604 Beachwood St, ',
#  'Attn: Lawson Williams, 1314 E County Road 124',
#  '2512 County Road 316, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '22740 Brook Forest Rd., ',
#  'Attn: Shawn Laughlin, 107 Green Gables Ct',
#  '516 SOUTH MAIN STREET, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '15441 Lake Rd, ',
#  '110 Broken Bough Ln, ',
#  '407 Devlin Shores Dr, ',
#  'XXXXX, ',
#  '16771 Rabon Chapel Rd, ',
#  '33114 Forest West St, ',
#  'XXXXX, ',
#  '23846 NORTHCREST TRL, ',
#  'XXXXX, ',
#  'Attn: Shawn Laughlin, 107 Green Gables Ct',
#  '14077 Horseshoe Bnd, ',
#  '160 Silverwood Ranch Dr, ',
#  'XXXXX, ',
#  '27630 E Benders Landing Blvd, ',
#  '30103 Marion Meadow Dr, ',
#  '5601 Fm 281, ',
#  '4536 NE STALLINGS DR, ',
#  '1440 W 7TH AVE, ',
#  '1440 W 7TH AVE, ',
#  'XXXXX, ',
#  '1609 Dobbins Rd, ',
#  '5296 Wagon Trail, ',
#  '8233 Leopard St Suite 3, ',
#  'Sharon Billings, 6438 Oak Ln',
#  '434 44th St, ',
#  'XXXXX, ',
#  '2543 Digger Ln, ',
#  'XXXXX, ',
#  '4017 Laguna Shores Rd, ',
#  'Attn: Adam Prosperie, 405 Parkside Dr',
#  '205 Henry St, ',
#  '260 Yupon St, ',
#  'XXXXX, ',
#  '7510 Highway 180 E, ',
#  'XXXXX, ',
#  '258 County Road 4211, ',
#  '1150 FT WORTH HWY, PO BOX 2947',
#  '104 Highland Dr, ',
#  '150 Beulah Rd, ',
#  '1008 Louise Ln, ',
#  'Attn: Cindy Moreno, 705 South Main Street',
#  '211 S Drake - 943, ',
#  'Attn: Krystal Hatfield, 17466 Us Hwy 59 N.',
#  'Attn: Eduardo Melero, 6214 NE 12 th Ave 202',
#  '5500 Sw 9th Ave, ',
#  '1415 Rs County Road 3345, ',
#  '4300 Tiffani Dr, ',
#  'XXXXX, ',
#  '2403 Russell Long Blvd, ',
#  '202 Commerce St, ',
#  'XXXXX, ',
#  '12750 Preston Road, Suite 1100 Building 11 ',
#  'XXXXX, ',
#  '707 Village Green Dr, ',
#  '359 Brushy Creek Ranch Rd, Spot 43',
#  '114 Melody Ln, ',
#  '312 N Main St, ',
#  'XXXXX, ',
#  '201 Forest Hill Top Ln, ',
#  '105 ZENNA DRIVE, ',
#  '1024 E Sinton St, ',
#  'Attn: Andrew Sisson, 8534 Highway 89',
#  '863 Harlan Ave, ',
#  '2710 25th St, Null',
#  'Attn: Steven Murphey, 7346 Harpers Ridge',
#  'Attn: Don Noland, 3326 Fm 2767',
#  'Brian Hazelton, 329 S Bonner Ave',
#  'Attn: Terry Nick, 538 W 6th St',
#  '3226 Spur 124, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '22821 Babes Lndg, ',
#  'XXXXX, ',
#  'Attn: Daniel Cardona, 2100 Design Rd',
#  '1503 Fairhaven Drive, ',
#  '1503 Fairhaven Drive, ',
#  '4112 GLENVIEW DR, ',
#  '4112 GLENVIEW DR, ',
#  'Attn: Chris Meyer, 812 S Blue Mound Rd',
#  '2316 Mirandesa Dr, ',
#  'Attn: Chris Meyer, 812 S Blue Mound Rd',
#  'Zach Garrison, 8800 S Freeway',
#  '211 NE 21ST ST, ',
#  '211 NE 21ST ST, ',
#  'F2902-1201, 16201 Three Wide Drive',
#  '4108 KELLER HICKS RD BLDG A, BUILDING A',
#  'Justin Litke, 2400 Cullen St',
#  'Erica Thompson, 2727 Premier St',
#  '3004 Shadow Dr W, ',
#  '1400 Paisley Dr, ',
#  '1684 Gale Dr, ',
#  '2228 Wembley Wood Ln, ',
#  '200 Madison Sq, ',
#  '2021 Heatherbrook Dr, ',
#  '1200 Texan Trl Ste 160, ',
#  '2609 Summit Ridge Dr, ',
#  'XXXXX, ',
#  '709 Green River Trl, ',
#  'XXXXX, ',
#  '4705 Lafayette Ave, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '3604 Pecos St, ',
#  'XXXXX, ',
#  '2008 Jessie Pl, ',
#  '6633 Fair Meadows Dr, ',
#  '6649 Ridgetop Dr, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '820 Sky Wood Ct, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '802 Nun Ct., ',
#  '802 Nun Ct., ',
#  'XXXXX, ',
#  '1974 Ross Ave, ',
#  '18 E 42nd St, ',
#  '2031 LOOP 306, ',
#  '1037 Blumentritt Rd, ',
#  '2727 Fm 812 Rd, Dg Roofing',
#  '10840 FM 812, ',
#  '3113 Murrelet Way, ',
#  'Attn: Natalie Dove, 22111 State Highway 71 Ste 301',
#  '606 TRINITY ST, ',
#  'Carlo Ray, 800 West 6th Street',
#  '4701 E 5TH ST, ',
#  '1900 Riverview St, ',
#  '4701 E 5TH ST, ',
#  '4701 E 5TH ST, ',
#  '3001 E CESAR CHAVEZ ST, ',
#  '1401 E 5th St, ',
#  '3001 E CESAR CHAVEZ ST, ',
#  '5820 Harper Park Dr Unit 67, ',
#  '3300 Graybuck Rd, ',
#  'Attn: Kayla Conklin, 1001 W. HOWARD LN.',
#  '102 Duck Lake Dr, ',
#  '13208 Viento Del Sur St, ',
#  '1905 Topaz Rd, ',
#  'XXXXX, ',
#  '202 Nueces St Unit 2006, ',
#  'XXXXX, ',
#  '1604 Broadmoor Dr, ',
#  '1604 Broadmoor Dr, ',
#  '8210 SPRINGDALE ROAD, ',
#  '5207 Branding Chase St, ',
#  '4816 Paraiso Pkwy, ',
#  'XXXXX, ',
#  'Attn: Rhebecca Zeimet, 11517 Jim Thorpe Ln',
#  '658 Canion St, ',
#  '10606 Bluff Bend Dr, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '10519 BOYER BLVD, ',
#  '12633 Research Blvd, ',
#  '11500 Jollyville Rd Apt 923, Bldg 9',
#  'XXXXX, ',
#  'XXXXX, ',
#  '910 HWY 69 S, ',
#  'Jose Barrientos, 5059 Garner Field Rd',
#  '340 Pecan St, ',
#  'Attn: Charles Prater, 301 W. Pine 200',
#  '3120 Vz County Road 2318, ',
#  '21546 State Highway 19, ',
#  'Attn: Ron Yager, 1501 Goodnight Blvd',
#  'Attn: David Marshall, 3108 E Red River St',
#  '3103 Coffey St Apt 6, ',
#  '907 Durango St, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  'Steven Stanfield, 146b Fm 2793',
#  'XXXXX, ',
#  '83 Windmill Dr, ',
#  '20738 Stokes Rd, ',
#  'XXXXX, ',
#  'Kim Limmer, 2579 Fm 389',
#  '101 Guadalupe St, ',
#  'XXXXX, ',
#  '406 County Road 100, ',
#  '3010 Lombard Dr, ',
#  '15794 Fm 1954, ',
#  '15794 Fm 1954, ',
#  'XXXXX, ',
#  'Attn: Dominic Ruggiero, 2531 Double Creek Dr',
#  'All Surface Renew, 1713 Lightfoot Drive',
#  'Attn: Shane Ha, 7120 Avignon Dr.',
#  '205 Quail Ln, ',
#  '1221 Calendula Trl, ',
#  'XXXXX, ',
#  'XXXXX, ',
#  '6819 N Lakewoods Dr, ',
#  '21810 Cold Spring Dr # A, ',
#  '3300 Gattis School Rd, ',
#  '1161 Stone Forest Trl, ',
#  '13116 Coriander Dr, ',
#  '109 N Tranquility Dr, ',
#  'Buffie Pryor, 1870 Illinois St',
#  'Attn: Randy Warnell, 109 Private Road 1309',
#  '824 Virginia St, ']

# %%
usaddress.tag(list_add[9-2])
# Out:
# (OrderedDict([('OccupancyType', 'XXXXX')]), 'Ambiguous')

# %%
usaddress.tag('817 N Bryant St Ste C')
# Out:
# (OrderedDict([('AddressNumber', '817'),
#               ('StreetNamePreDirectional', 'N'),
#               ('StreetName', 'Bryant'),
#               ('StreetNamePostType', 'St'),
#               ('OccupancyType', 'Ste'),
#               ('OccupancyIdentifier', 'C')]),
#  'Street Address')
